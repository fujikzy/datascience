# %%
#散布図行列
#sns.pairplot(data, hue="species", size=2.5)

#正規表現
#jobseeker["schoolr"] = jobseeker.school.str.match("(私立|国立|学校法人)?[ |　]?(?!.*大学付属)(.*?大学)").str.get(1)

#JOIN
#jobseeker = pandas.merge(jobseeker, college_level, how="left", left_on="schoolr", right_on="name")

#数値変換
#jobseeker["nen"] = 2015 - (jobseeker.birth.str[0:4]).convert_objects(convert_numeric=True)

#str変換
#rec.js1 = [str(js) for js in rec.js1] #求職者親Noがintとstr混在のため

###特徴エンジニアリング
新たに計測されたデータではなく、既存の特徴量から計算された特徴量を作成すること
###特徴選択

処理速度を早めるために、多くの特徴量がある中から有用な特徴量だけを選択すること

# %% [markdown]
# ###ライブラリ

# %%
from IPython.display import display
from matplotlib import pyplot as plt
from sklearn.datasets import load_iris
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn import preprocessing
from sklearn import cross_validation
from sklearn import grid_search
from sklearn import ensemble, svm, linear_model
import numpy as np
import pandas as pd
import seaborn as sns

pd.set_option('precision',3)

#-----------------------------------------------------------------------------------------
def check_input_rate(df):
    
    df = pd.concat([df.dtypes,                            #型
                                df.count(),                           #入力数
                                len(df) - df.count(),            #NaN数
                                df.count() / len(df) * 100 #入力率
                                ], axis=1)
    df.columns = ["型","入力数","NaN数","入力率"]
    
    return df

#-----------------------------------------------------------------------------------------
def check_column_data(df, value):
    
    df = df.replace(np.NaN, "null") #NaNをカウントするため置換
    df = pd.concat([df.groupby(value).size(), 
                                df.groupby(value).size() / df[value].count() * 100],
                                axis = 1)
    df = df.rename(index={"null":"NaN"},
                               columns = {0:"件数", 1:"割合"})
    
    return df

#-----------------------------------------------------------------------------------------
def check_evaluation(test_cls, pred_cls):
    
    #MATRIX
    matrix = pd.DataFrame(confusion_matrix(test_cls, pred_cls))
    matrix.columns.name, matrix.index.name = "予測", "実績"
    display(matrix)

    #EVALUATION
    p, r, f, s = precision_recall_fscore_support(test_cls, pred_cls, beta=0.5)
    evaluation = pd.DataFrame({'precision': p, 'recall': r, 'score(F)': f, 'support':s})
    display(evaluation)

# %% [markdown]
# ###データ - 読込

# %%
#names = ["survived","pclass","sex","age","sibsp","fare","embarked","class","who","adult_male","deck","embark_town","alive","alone"]
#data= pandas.read_csv("./xxxx.tsv", sep = "\t", header = None, names = names)
data = sns.load_dataset("titanic")
data.head(5)
# Out:
#    survived  pclass     sex  age  sibsp  parch   fare embarked  class    who  \
# 0         0       3    male   22      1      0   7.25        S  Third    man
# 1         1       1  female   38      1      0  71.28        C  First  woman
# 2         1       3  female   26      0      0   7.92        S  Third  woman
# 3         1       1  female   35      1      0  53.10        S  First  woman
# 4         0       3    male   35      0      0   8.05        S  Third    man
#
#   adult_male deck  embark_town alive  alone
# 0       True  NaN  Southampton    no  False
# 1      False    C    Cherbourg   yes  False
# 2      False  NaN  Southampton   yes   True
# 3      False    C  Southampton   yes  False
# 4       True  NaN  Southampton    no   True

# %% [markdown]
# ###データ - 型変換

# %%
## null文字 to NaN
data = data.replace("null", np.NaN)

## date to datetime64型
data["ver"] = "2015-01-01"
data["ver"] = pd.to_datetime(data["ver"])

# %% [markdown]
# ###データ - 各カラムの入力率

# %%
check_input_rate(data).T
# Out:
#      survived pclass     sex      age  sibsp  parch     fare embarked   class  \
# 型       int64  int64  object  float64  int64  int64  float64   object  object
# 入力数       891    891     891      714    891    891      891      889     891
# NaN数        0      0       0      177      0      0        0        2       0
# 入力率       100    100     100     80.1    100    100      100     99.8     100
#
#          who adult_male    deck embark_town   alive alone             ver
# 型     object       bool  object      object  object  bool  datetime64[ns]
# 入力数      891        891     203         889     891   891             891
# NaN数       0          0     688           2       0     0               0
# 入力率      100        100    22.8        99.8     100   100             100

# %% [markdown]
# ###データ - 削除

# %%
###NaNレコード削除
data = data.dropna(subset=["age","embarked"]) 
###カラム削除
data = data.drop(["deck"], axis = 1)
###INDEXリセット
data = data.reset_index(drop = True)

check_input_rate(data).T
# Out:
#      survived pclass     sex      age  sibsp  parch     fare embarked   class  \
# 型       int64  int64  object  float64  int64  int64  float64   object  object
# 入力数       712    712     712      712    712    712      712      712     712
# NaN数        0      0       0        0      0      0        0        0       0
# 入力率       100    100     100      100    100    100      100      100     100
#
#          who adult_male embark_town   alive alone             ver
# 型     object       bool      object  object  bool  datetime64[ns]
# 入力数      712        712         712     712   712             712
# NaN数       0          0           0       0     0               0
# 入力率      100        100         100     100   100             100

# %% [markdown]
# ###データ - 基礎統計量

# %%
data.describe()
# Out:
#        survived  pclass     age   sibsp   parch    fare adult_male  alone  \
# count    712.00  712.00  712.00  712.00  712.00  712.00        712    712
# mean       0.40    2.24   29.64    0.51    0.43   34.57       0.58  0.565
# std        0.49    0.84   14.49    0.93    0.85   52.94      0.494  0.496
# min        0.00    1.00    0.42    0.00    0.00    0.00      False  False
# 25%        0.00    1.00   20.00    0.00    0.00    8.05          0      0
# 50%        0.00    2.00   28.00    0.00    0.00   15.65          1      1
# 75%        1.00    3.00   38.00    1.00    1.00   33.00          1      1
# max        1.00    3.00   80.00    5.00    6.00  512.33       True   True
#
#         age_b  female_d  male_d     age_n
# count  712.00    712.00  712.00  7.12e+02
# mean     3.51      0.36    0.64  2.99e-16
# std      1.46      0.48    0.48  1.00e+00
# min      1.00      0.00    0.00 -2.02e+00
# 25%      3.00      0.00    0.00 -6.65e-01
# 50%      3.00      0.00    1.00 -1.13e-01
# 75%      4.00      1.00    1.00  5.77e-01
# max      7.00      1.00    1.00  3.47e+00

# %% [markdown]
# ###データ - 各カラムの入力データ割合

# %%
for column in data.columns:
    display(check_column_data(data, column).sort("件数", ascending=False).T) #降順･転置
# Out:
# survived       0       1
# 件数        424.00  288.00
# 割合         59.55   40.45
# pclass       3       1      2
# 件数      355.00  184.00  173.0
# 割合       49.86   25.84   24.3
# sex    male  female
# 件数   453.00  259.00
# 割合    63.62   36.38
# age  24.00  22.00  18.00  30.00  28.00  19.00  21.00  25.00  36.00  29.00  \
# 件数   30.00  27.00  26.00  25.00  25.00  25.00  24.00  23.00  22.00  20.00
# 割合    4.21   3.79   3.65   3.51   3.51   3.51   3.37   3.23   3.09   2.81
#
# age  ...    36.50  34.50  0.67   24.50  23.50  20.50  14.50  12.00  0.92   \
# 件数   ...     1.00   1.00   1.00   1.00   1.00   1.00   1.00   1.00   1.00
# 割合   ...     0.14   0.14   0.14   0.14   0.14   0.14   0.14   0.14   0.14
#
# age  80.00
# 件数    1.00
# 割合    0.14
#
# [2 rows x 88 columns]
# sibsp       0      1      2      4      3    5
# 件数     469.00  183.0  25.00  18.00  12.00  5.0
# 割合      65.87   25.7   3.51   2.53   1.69  0.7
# parch       0       1      2    3    5     4     6
# 件数     519.00  110.00  68.00  5.0  5.0  4.00  1.00
# 割合      72.89   15.45   9.55  0.7  0.7  0.56  0.14
# fare  13.00  26.00  8.05   10.50  7.90   7.92   7.78   7.75   7.85   26.55  \
# 件数    41.00  30.00  29.00  24.00  23.00  18.00  14.00  14.00  13.00  13.00
# 割合     5.76   4.21   4.07   3.37   3.23   2.53   1.97   1.97   1.83   1.83
#
# fare  ...    34.02  33.50  32.50  32.32  8.68   8.85   30.70  9.22   28.71  \
# 件数    ...     1.00   1.00   1.00   1.00   1.00   1.00   1.00   1.00   1.00
# 割合    ...     0.14   0.14   0.14   0.14   0.14   0.14   0.14   0.14   0.14
#
# fare  22.52
# 件数     1.00
# 割合     0.14
#
# [2 rows x 219 columns]
# embarked       S       C      Q
# 件数        554.00  130.00  28.00
# 割合         77.81   18.26   3.93
# class   Third   First  Second
# 件数     355.00  184.00   173.0
# 割合      49.86   25.84    24.3
# who     man   woman  child
# 件数   413.00  216.00  83.00
# 割合    58.01   30.34  11.66
# adult_male   True    False
# 件数          413.00  299.00
# 割合           58.01   41.99
# embark_town  Southampton  Cherbourg  Queenstown
# 件数                554.00     130.00       28.00
# 割合                 77.81      18.26        3.93
# alive      no     yes
# 件数     424.00  288.00
# 割合      59.55   40.45
# alone   True    False
# 件数     402.00  310.00
# 割合      56.46   43.54
# ver  2015-01-01
# 件数          712
# 割合          100

# %% [markdown]
# ###前処理 - ビン化
# 連続数値を各区分にグループ化

# %%
bins = [0,10,20,30,40,50,60,100]
labels = [1,2,3,4,5,6,7]
data["age_b"] = pd.cut(data.age, bins, labels = labels, right = False) #左閉空間

#データ確認
display(check_column_data(data, "age_b").rename(index = {1:"10代未満", 2:"10代", 3:"20代", 4:"30代", 5:"40代", 6:"50代", 7:"60代以上", "null":"NaN"}).T)
# Out:
# age_b  10代未満     10代    20代     30代   40代    50代  60代以上
# 件数     62.00  102.00  220.0  166.00  89.0  48.00  25.00
# 割合      8.71   14.33   30.9   23.31  12.5   6.74   3.51

# %% [markdown]
# ###前処理 - ダミー変数化
# カテゴリ変数を0/1のデータに変換

# %%
sex_d = pd.get_dummies(data.sex)
sex_d = sex_d.rename(columns={'male': 'male_d', 'female': 'female_d'})
data = pd.concat([data, sex_d], axis = 1)

#データ確認
data[["sex","male_d","female_d"]].head(5)
# Out:
#       sex  male_d  female_d
# 0    male       1         0
# 1  female       0         1
# 2  female       0         1
# 3  female       0         1
# 4    male       1         0

# %% [markdown]
# ###前処理 - 正規化
# 各特徴量の重要性を均一化

# %%
for col in ["age"]:
    data[col + "_n"] = (data[col] - data[col].mean()) / data[col].std()

#データ確認
data[["age","age_n"]].head(5)
# Out:
#    age  age_n
# 0   22  -0.53
# 1   38   0.58
# 2   26  -0.25
# 3   35   0.37
# 4   35   0.37

# %% [markdown]
# ###学習データ・テストデータ作成

# %%
columns = ["pclass", "age", "age_n", "female_d", "male_d"]
features = data[columns]
cls = data.survived

train_features, test_features, train_cls, test_cls = cross_validation.train_test_split(features, cls, train_size=0.8, random_state=0)

# %% [markdown]
# ###Random Forest
# * [RandomForestのグリッドサーチ](http://blog.tatsushim.com/?p=63)
# * [最適なグリッドサーチ](http://sssslide.com/speakerdeck.com/anaguma2261/scikit-learndexue-buji-jie-xue-xi-ru-men)
# * [SVM実践ガイド](http://www.slideshare.net/sleepy_yoshi/svm-13435949)

# %%
#Grid-Search
estimator = ensemble.RandomForestClassifier()
param_grid = {
        'n_estimators'      : [10,20,30],
        'n_jobs'            : [1],
        'min_samples_split' : [2],
        'min_samples_leaf'  : [1]
}
model = grid_search.GridSearchCV(estimator, param_grid)

#Fit-Predict
model.fit(train_features, train_cls)
pred_cls = model.predict(test_features)

#Importance
importances = pd.DataFrame(columns)
importances["value"] = model.best_estimator_.feature_importances_
display(importances.sort("value", ascending=False).T)

#Evaluation
check_evaluation(test_cls, pred_cls)
# Out:
#            2     1       0         3       4
# 0      age_n   age  pclass  female_d  male_d
# value   0.22  0.21   0.209     0.201   0.161
# 予測   0   1
# 実績
# 0   75   7
# 1   14  47
#    precision  recall  score(F)  support
# 0       0.84    0.91      0.86       82
# 1       0.87    0.77      0.85       61

# %% [markdown]
# ###K-FoldCrossValidation
# データセットをK個にブロックに分割し、1つのブロックを除いたデータ集合でモデルを学習し、残りのブロックで評価を行うことをK回繰り返す交差検定は汎化能力を持つか判断するためであり、最終的なモデルは全データセットを利用する

# %%
kf = cross_validation.KFold(len(features), n_folds=10)
precision_list = []
recall_list = []

for train_index, test_index in kf:
    
    model.fit(features.iloc[train_index], cls[train_index])
    pred_cls = model.predict(features.iloc[test_index])
    precision_list.append(precision_score(cls[test_index], pred_cls, average=None)[1] )
    recall_list.append(recall_score(cls[test_index], pred_cls, average=None)[1] )

print("適合率", np.mean(precision_list))
print("再現率", np.mean(recall_list))
# Out:
# 適合率 0.788254803676
# 再現率 0.711039519229

# %% [markdown]
# # 正規化
#
# ###ストップワード
# 頻繁に使われる単語など分類に貢献したい単語
# ###ステミング
# 意味的に同じである単語を特定の語幹へ変換
#
# [pythonでの自然言語処理](https://github.com/pika-shi/sphinx_information_retrieval/blob/master/natural_language_processing.rst)
#
# #ベクトル化
# ###bag-of-word
# 単語の出現回数を特徴量の重みとする方法
# ###TF-IDF(Term Frequency - inverse document frequency)
# 特定の文書で出現する単語の重みを大きくし、あらゆる文書で出現する単語の重みを小さくする手法

# %%
from sklearn.feature_extraction.text import CountVectorizer

#コンテンツ
content = ["This is a toy post about machine learning. Actually, it contains not mush intersting stuff.", 
                    "Imaging databases can get huge.",
                    "Most imaging databases safe images permanently.",
                    "Imaging databases store images.",
                    "Imaging databases store images. Imaging databases store images. Imaging databases store images.",]

#トークン化
vectorize = CountVectorizer(min_df = 1, stop_words = ["stop_A","stop_B"])
x = vectorize.fit_transform(content) # bag-of-word
num_sample, num_feature = x.shape

print(num_sample,num_feature)
print(vectorize.get_feature_names())
# Out:
# 5 24
# ['about', 'actually', 'can', 'contains', 'databases', 'get', 'huge', 'images', 'imaging', 'intersting', 'is', 'it', 'learning', 'machine', 'most', 'mush', 'not', 'permanently', 'post', 'safe', 'store', 'stuff', 'this', 'toy']

# %% [markdown]
# # トピックモデル
# ###潜在的ディレクトリ配分法(LDA)
# * [word cloud](http://qiita.com/kenmatsu4/items/9b6ac74f831443d29074)

# %%
from gensim import corpora,models,similarities

# %%
import mecab
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-130312f576e4> in <module>()
# ----> 1 import mecab
#
# ImportError: No module named 'mecab'

# %% [markdown]
# #次元圧縮
# ###主成分分析(PCA)
# * [PCAとkmeans](http://kensuke-mi.xyz/kensuke-mi_diary/2014/08/pcakmeans.html)
